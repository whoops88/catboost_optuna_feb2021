# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, KFold
import catboost as cb
import optuna
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/tabular-playground-series-feb-2021/sample_submission.csv
# /kaggle/input/tabular-playground-series-feb-2021/train.csv
# /kaggle/input/tabular-playground-series-feb-2021/test.csv

# %%
train = pd.read_csv('/kaggle/input/tabular-playground-series-feb-2021/train.csv')
test = pd.read_csv('/kaggle/input/tabular-playground-series-feb-2021/test.csv')
submission = pd.read_csv( '/kaggle/input/tabular-playground-series-feb-2021/sample_submission.csv', index_col='id')

# %%
data = pd.concat([train, test])

# %%
# scaler = StandardScaler()
# data.iloc[:,11:-1]= scaler.fit_transform(data.iloc[:,11:-1])

# %%
data = pd.get_dummies(data)
train = data[:300000]
test = data[300000:]
del data

# %%
X=train.drop(['id', 'target'],axis=1)
y=train.target
test = test.drop(['id', 'target'],axis=1)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state=23)

# %%
categ_features = X.iloc[:,14:].columns

# %%
def objective(trial):
    X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3)
    params = {
        'cat_features': categ_features,
        'eval_metric': 'RMSE',
        'loss_function' :'RMSE',
        'random_state': 23,
        'use_best_model':True,
        'task_type': 'GPU',
        'iterations': trial.suggest_int('iterations', 100, 10000),
        'depth': trial.suggest_int('depth', 2, 16),
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1.0),
        'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-8, 100),
#         'num_leaves': trial.suggest_int('num_leaves', 2, 256),
        'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 1e-2, 10.0),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
    }
    
    model = cb.CatBoostRegressor(**params)
    
    model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)], verbose=0, early_stopping_rounds=200)
    predictions = model.predict(X_valid)
    score = mean_squared_error(y_valid, predictions)
    return score

# %%
# %%time
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=40)
# Out:
# [I 2021-02-26 18:27:54,268] A new study created in memory with name: no-name-79f6d648-a3ed-482a-85ea-6ea6cf2c66ff
# [I 2021-02-26 18:30:11,420] Trial 0 finished with value: 0.7808049826884593 and parameters: {'iterations': 2049, 'depth': 2, 'learning_rate': 0.0008205761099115174, 'l2_leaf_reg': 6.233469768268151, 'bagging_temperature': 0.3984055179876004, 'min_child_samples': 15}. Best is trial 0 with value: 0.7808049826884593.
# [I 2021-02-26 18:31:52,661] Trial 1 finished with value: 0.7139542928559558 and parameters: {'iterations': 5218, 'depth': 5, 'learning_rate': 0.027374458133222687, 'l2_leaf_reg': 5.7578023556884115e-05, 'bagging_temperature': 0.6180657263771288, 'min_child_samples': 99}. Best is trial 1 with value: 0.7139542928559558.
# [I 2021-02-26 18:33:04,586] Trial 2 finished with value: 0.7142668339229633 and parameters: {'iterations': 4894, 'depth': 5, 'learning_rate': 0.2693565442338347, 'l2_leaf_reg': 5.764374178897066e-07, 'bagging_temperature': 2.6876513980622083, 'min_child_samples': 46}. Best is trial 1 with value: 0.7139542928559558.
# [I 2021-02-26 18:34:23,312] Trial 3 finished with value: 0.766019702091021 and parameters: {'iterations': 883, 'depth': 9, 'learning_rate': 0.002352396186201235, 'l2_leaf_reg': 86.43028245218014, 'bagging_temperature': 0.03593175343629343, 'min_child_samples': 32}. Best is trial 1 with value: 0.7139542928559558.
# [I 2021-02-26 18:36:26,125] Trial 4 finished with value: 0.7178505712682329 and parameters: {'iterations': 5870, 'depth': 9, 'learning_rate': 0.005068571642693296, 'l2_leaf_reg': 0.8859634197929094, 'bagging_temperature': 0.10290763265876304, 'min_child_samples': 85}. Best is trial 1 with value: 0.7139542928559558.
# [I 2021-02-26 19:08:43,063] Trial 24 finished with value: 0.7179695278985284 and parameters: {'iterations': 6034, 'depth': 6, 'learning_rate': 0.1125502970665127, 'l2_leaf_reg': 0.0031869471210869364, 'bagging_temperature': 0.06474691484793571, 'min_child_samples': 52}. Best is trial 17 with value: 0.7114697776224905.
# [I 2021-02-26 19:09:58,214] Trial 25 finished with value: 0.7123603591841516 and parameters: {'iterations': 8579, 'depth': 3, 'learning_rate': 0.2532937545618855, 'l2_leaf_reg': 1.0901864470245403e-06, 'bagging_temperature': 0.14406678953758079, 'min_child_samples': 89}. Best is trial 17 with value: 0.7114697776224905.
# [I 2021-02-26 19:11:12,580] Trial 26 finished with value: 0.7192320936243212 and parameters: {'iterations': 4149, 'depth': 3, 'learning_rate': 0.2863563521682685, 'l2_leaf_reg': 7.365708091608343e-07, 'bagging_temperature': 0.1995005775979305, 'min_child_samples': 92}. Best is trial 17 with value: 0.7114697776224905.
# [I 2021-02-26 19:12:25,814] Trial 27 finished with value: 0.7113293879285506 and parameters: {'iterations': 8315, 'depth': 3, 'learning_rate': 0.5857687310544913, 'l2_leaf_reg': 2.364246562962328e-06, 'bagging_temperature': 0.35012527515317604, 'min_child_samples': 90}. Best is trial 27 with value: 0.7113293879285506.
# [I 2021-02-26 19:13:37,875] Trial 28 finished with value: 0.7177126563999999 and parameters: {'iterations': 8441, 'depth': 3, 'learning_rate': 0.9695754474348797, 'l2_leaf_reg': 2.59273751776459e-06, 'bagging_temperature': 0.4272582301723084, 'min_child_samples': 90}. Best is trial 27 with value: 0.7113293879285506.
# [I 2021-02-26 19:15:26,920] Trial 29 finished with value: 0.7357729964919191 and parameters: {'iterations': 9930, 'depth': 2, 'learning_rate': 0.00212935853693677, 'l2_leaf_reg': 1.823074698373243e-08, 'bagging_temperature': 0.44385342303819036, 'min_child_samples': 100}. Best is trial 27 with value: 0.7113293879285506.
# [I 2021-02-26 19:16:40,494] Trial 30 finished with value: 0.712470953129531 and parameters: {'iterations': 6169, 'depth': 4, 'learning_rate': 0.47341298394290815, 'l2_leaf_reg': 4.004937210918712e-05, 'bagging_temperature': 0.1201018967169307, 'min_child_samples': 84}. Best is trial 27 with value: 0.7113293879285506.
# [I 2021-02-26 19:17:53,779] Trial 31 finished with value: 0.716022953939842 and parameters: {'iterations': 5852, 'depth': 4, 'learning_rate': 0.44906044257957883, 'l2_leaf_reg': 0.00010194981952627781, 'bagging_temperature': 0.10302089627152691, 'min_child_samples': 86}. Best is trial 27 with value: 0.7113293879285506.
# [I 2021-02-26 19:19:07,013] Trial 32 finished with value: 0.7189643099184225 and parameters: {'iterations': 6483, 'depth': 4, 'learning_rate': 0.8731122829736845, 'l2_leaf_reg': 3.2412338425336176e-07, 'bagging_temperature': 0.34191429547299174, 'min_child_samples': 78}. Best is trial 27 with value: 0.7113293879285506.
# [I 2021-02-26 19:20:21,055] Trial 33 finished with value: 0.7184985456988449 and parameters: {'iterations': 5489, 'depth': 2, 'learning_rate': 0.2899820468938474, 'l2_leaf_reg': 2.802007205459236e-05, 'bagging_temperature': 0.1370447989048558, 'min_child_samples': 97}. Best is trial 27 with value: 0.7113293879285506.
# [I 2021-02-26 19:21:39,245] Trial 34 finished with value: 0.7167697615560567 and parameters: {'iterations': 8495, 'depth': 4, 'learning_rate': 0.16188549667917218, 'l2_leaf_reg': 1.3903826152351135e-06, 'bagging_temperature': 0.7080911765128387, 'min_child_samples': 83}. Best is trial 27 with value: 0.7113293879285506.
# [I 2021-02-26 19:22:53,549] Trial 35 finished with value: 0.7170265928663965 and parameters: {'iterations': 7427, 'depth': 3, 'learning_rate': 0.524977740632931, 'l2_leaf_reg': 1.2057323298188996e-07, 'bagging_temperature': 0.05605686063968237, 'min_child_samples': 89}. Best is trial 27 with value: 0.7113293879285506.
# [I 2021-02-26 19:24:36,333] Trial 36 finished with value: 0.7177098904554874 and parameters: {'iterations': 4578, 'depth': 6, 'learning_rate': 0.028310484765122955, 'l2_leaf_reg': 6.041597027218445e-05, 'bagging_temperature': 1.5925012351358458, 'min_child_samples': 94}. Best is trial 27 with value: 0.7113293879285506.
# [I 2021-02-26 19:26:20,100] Trial 37 finished with value: 0.7288820385852294 and parameters: {'iterations': 6216, 'depth': 4, 'learning_rate': 0.00399329775789956, 'l2_leaf_reg': 2.641730933487444e-06, 'bagging_temperature': 0.1381852492144898, 'min_child_samples': 80}. Best is trial 27 with value: 0.7113293879285506.
# [I 2021-02-26 19:28:14,645] Trial 38 finished with value: 0.7593386400819448 and parameters: {'iterations': 6837, 'depth': 6, 'learning_rate': 0.0009587447271388308, 'l2_leaf_reg': 0.000286936103071796, 'bagging_temperature': 0.02066297761772039, 'min_child_samples': 73}. Best is trial 27 with value: 0.7113293879285506.
# [I 2021-02-26 19:29:47,471] Trial 39 finished with value: 0.7196234970822438 and parameters: {'iterations': 5557, 'depth': 2, 'learning_rate': 0.014379071184423869, 'l2_leaf_reg': 0.0016255432013883445, 'bagging_temperature': 0.2624621074020319, 'min_child_samples': 87}. Best is trial 27 with value: 0.7113293879285506.
# CPU times: user 1h 3min 33s, sys: 6min 17s, total: 1h 9min 51s
# Wall time: 1h 1min 53s

# %%
trial = study.best_trial
print(f" best RMSE: {trial.value}")
print("best params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")
# Out:
#  best RMSE: 0.7113293879285506
# best params:
#     iterations: 8315
#     depth: 3
#     learning_rate: 0.5857687310544913
#     l2_leaf_reg: 2.364246562962328e-06
#     bagging_temperature: 0.35012527515317604
#     min_child_samples: 90

# %%
# %%time
# params1 = { 
#     'iterations': 7827,
#     'depth': 6, 
#     'learning_rate': 0.06115296942277834, 
#     'l2_leaf_reg': 0.00018537808841101856, 
#     'bagging_temperature': 7.2769130916283125, 
#     'min_child_samples': 95
# }


# model_cb = cb.CatBoostRegressor(**params1, cat_features=categ_features ,
#                                 loss_function='RMSE', eval_metric='RMSE')

# model_cb.fit(X, y, cat_features=categ_features)
# submission['target'] = model_cb.predict(test)
# submission.to_csv('catboost4.csv')

# %%
# %%time
# params2 = {
#     'iterations': 6961, 
#     'depth': 13, 
#     'learning_rate': 0.1420713844582006, 
#     'l2_leaf_reg': 0.0019005856806734837, 
#     'bagging_temperature': 5.060337163809838, 
#     'min_child_samples': 49
# }


# model_cb = cb.CatBoostRegressor(**params2, cat_features=categ_features ,
#                                 loss_function='RMSE', eval_metric='RMSE')

# model_cb.fit(X, y, cat_features=categ_features)
# submission['target'] = model_cb.predict(test)
# submission.to_csv('catboost3.csv')

# %%
n_folds = 10
train_oof = np.zeros((300000,))
test_preds = 0

skf = KFold(n_splits=n_folds, random_state=23, shuffle=True)

for fold, (train_index, test_index) in enumerate(skf.split(X, y)):
    
    print(f'FOLD    {fold+1}')
    
    X_train, X_valid = pd.DataFrame(X.iloc[train_index]), pd.DataFrame(X.iloc[test_index])
    y_train, y_valid = y.iloc[train_index], y.iloc[test_index]
       
    cat_params = { 
        'iterations': 7827,
        'depth': 6, 
        'learning_rate': 0.06115296942277834, 
        'l2_leaf_reg': 0.00018537808841101856, 
        'bagging_temperature': 7.2769130916283125, 
        'min_child_samples': 95
    }
    
    model = cb.CatBoostRegressor(
        **cat_params
    )
    model.fit(
        X_train, 
        y_train,
        eval_set=[(X_valid, y_valid)],
        verbose=500,
        early_stopping_rounds=200,
    )
    preds = model.predict(X_valid)
    test_preds += model.predict(test) / n_folds
    train_oof[test_index] = preds
    print("")
    

print(f": RMSE = {mean_squared_error(y, train_oof)}")

submission['target'] = test_preds
submission.to_csv('catboost_optuna_scaled.csv')
# Out:
# FOLD    1
# 0:	learn: 0.8854431	test: 0.8856635	best: 0.8856635 (0)	total: 61ms	remaining: 7m 57s
# 500:	learn: 0.8380577	test: 0.8426577	best: 0.8426577 (500)	total: 25.5s	remaining: 6m 13s
# 1000:	learn: 0.8282445	test: 0.8412879	best: 0.8412879 (1000)	total: 50.9s	remaining: 5m 46s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.8411194697
# bestIteration = 1135
#
# Shrink model to first 1136 iterations.
#
# FOLD    2
# 0:	learn: 0.8850368	test: 0.8874778	best: 0.8874778 (0)	total: 50ms	remaining: 6m 30s
# 500:	learn: 0.8376263	test: 0.8461418	best: 0.8461418 (500)	total: 24.9s	remaining: 6m 4s
# 1000:	learn: 0.8276183	test: 0.8450314	best: 0.8449502 (926)	total: 50.4s	remaining: 5m 43s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.8448790229
# bestIteration = 1220
#
# Shrink model to first 1221 iterations.
#
# FOLD    3
# 0:	learn: 0.8854179	test: 0.8857940	best: 0.8857940 (0)	total: 48.9ms	remaining: 6m 22s
# 500:	learn: 0.8376292	test: 0.8461892	best: 0.8461892 (500)	total: 24.6s	remaining: 5m 59s
# 1000:	learn: 0.8279331	test: 0.8446564	best: 0.8446421 (984)	total: 49.8s	remaining: 5m 39s
# 1500:	learn: 0.8194723	test: 0.8442666	best: 0.8442448 (1401)	total: 1m 15s	remaining: 5m 16s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.8442267275
# bestIteration = 1598
#
# Shrink model to first 1599 iterations.
#
# FOLD    4
# 0:	learn: 0.8857859	test: 0.8826020	best: 0.8826020 (0)	total: 47.7ms	remaining: 6m 13s
# 500:	learn: 0.8380297	test: 0.8410633	best: 0.8410633 (500)	total: 25.4s	remaining: 6m 11s
# 1000:	learn: 0.8281862	test: 0.8398579	best: 0.8398579 (1000)	total: 50.9s	remaining: 5m 47s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.8397148218
# bestIteration = 1145
#
# Shrink model to first 1146 iterations.
#
# FOLD    5
# 0:	learn: 0.8852649	test: 0.8873337	best: 0.8873337 (0)	total: 47.9ms	remaining: 6m 15s
# 500:	learn: 0.8375989	test: 0.8458879	best: 0.8458879 (500)	total: 25.3s	remaining: 6m 10s
# 1000:	learn: 0.8277274	test: 0.8447505	best: 0.8447505 (1000)	total: 50s	remaining: 5m 40s
# 1500:	learn: 0.8192847	test: 0.8445985	best: 0.8445494 (1465)	total: 1m 14s	remaining: 5m 14s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.844548426
# bestIteration = 1601
#
# Shrink model to first 1602 iterations.
#
# FOLD    6
# 0:	learn: 0.8854868	test: 0.8844828	best: 0.8844828 (0)	total: 96.1ms	remaining: 12m 32s
# 500:	learn: 0.8379667	test: 0.8437925	best: 0.8437914 (498)	total: 25s	remaining: 6m 5s
# 1000:	learn: 0.8281517	test: 0.8423185	best: 0.8423106 (997)	total: 49.7s	remaining: 5m 38s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.8422304336
# bestIteration = 1133
#
# Shrink model to first 1134 iterations.
#
# FOLD    7
# 0:	learn: 0.8857118	test: 0.8832054	best: 0.8832054 (0)	total: 51.3ms	remaining: 6m 41s
# 500:	learn: 0.8378468	test: 0.8429943	best: 0.8429935 (499)	total: 25.3s	remaining: 6m 9s
# 1000:	learn: 0.8279495	test: 0.8416821	best: 0.8416808 (939)	total: 49.9s	remaining: 5m 40s
# 1500:	learn: 0.8194352	test: 0.8415345	best: 0.8415000 (1377)	total: 1m 14s	remaining: 5m 12s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.8414999573
# bestIteration = 1377
#
# Shrink model to first 1378 iterations.
#
# FOLD    8
# 0:	learn: 0.8847399	test: 0.8913626	best: 0.8913626 (0)	total: 49.6ms	remaining: 6m 28s
# 500:	learn: 0.8372528	test: 0.8487487	best: 0.8487487 (500)	total: 24.4s	remaining: 5m 57s
# 1000:	learn: 0.8274450	test: 0.8471382	best: 0.8471380 (996)	total: 49.2s	remaining: 5m 35s
# 1500:	learn: 0.8191186	test: 0.8468983	best: 0.8468802 (1421)	total: 1m 14s	remaining: 5m 12s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.8468801611
# bestIteration = 1421
#
# Shrink model to first 1422 iterations.
#
# FOLD    9
# 0:	learn: 0.8859735	test: 0.8808659	best: 0.8808659 (0)	total: 48.8ms	remaining: 6m 21s
# 500:	learn: 0.8380951	test: 0.8415638	best: 0.8415634 (499)	total: 25.4s	remaining: 6m 11s
# 1000:	learn: 0.8282023	test: 0.8403062	best: 0.8402951 (999)	total: 50.1s	remaining: 5m 41s
# 1500:	learn: 0.8198491	test: 0.8400868	best: 0.8400234 (1422)	total: 1m 14s	remaining: 5m 12s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.8400233826
# bestIteration = 1422
#
# Shrink model to first 1423 iterations.
#
# FOLD    10
# 0:	learn: 0.8852384	test: 0.8855050	best: 0.8855050 (0)	total: 51.8ms	remaining: 6m 45s
# 500:	learn: 0.8373594	test: 0.8476093	best: 0.8476093 (500)	total: 24.6s	remaining: 5m 59s
# 1000:	learn: 0.8274302	test: 0.8469176	best: 0.8468604 (970)	total: 49.5s	remaining: 5m 37s
# 1500:	learn: 0.8190219	test: 0.8468029	best: 0.8467668 (1448)	total: 1m 14s	remaining: 5m 15s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.8467502687
# bestIteration = 1560
#
# Shrink model to first 1561 iterations.
#
# : RMSE = 0.7109709903797772
